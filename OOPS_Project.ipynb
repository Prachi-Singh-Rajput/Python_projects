# %%
class Cuisines:
    def __init__(rp):

        print("\t\t\t\t JMD Restaurant")
        print("\t\t\t\t started 2024")
        print("\t\t\t\t near Cokhi Dhani")
        print("\n\n\t\t\t\t MENU")

        x=["Rajasthani_Cuisine","Punjabi Cuisine","Gujrati Cuisine","Maharashtra Cuisine"]
        for k in x:
            print("\n\n",k)
    def Rajasthani_Cuisine(rp):
        x=["Dal Bati","Gatte ki khichdi","Shahi Gatte","Mirchi Bada","Kachoris"]
        y=[500,450,120,50,20]
        rajasthani_cuisine={"Rajasthsni food":x,"Price":y}
        import pandas as pd
        df=pd.DataFrame(rajasthani_cuisine)
        print("\n\n Rajasthani foods \n\n")
        print(df)
        d=[]
        while x:
            x=True
            b=int(input("Enter the position value:"))
            c=int(input("Enter the Quantity:"))
            z=y[b]
            ytotal=z*c
            d.append(ytotal)
            x=input("Do you want to reorder")
            if x=="no":
                print("Thank you")
                break
        t=sum(d)
        m=(t*0.10)
        k=t+m
        from colorama import Fore,Back,Style
        print(Fore.BLACK+Back.BLUE+Style.BRIGHT+"servicetax=10%")
        print("Total Amount:",t,"Rupees:")
        print("Total Amount including Service Tax:",k,"Rupees")
       
    def Punjabi_Cuisine(rp):
        x=["Aaloo ka Paratha","lassi","Dal Makhni","Rajma Chawal","Chole Bhature"]
        y=[40,30,100,120,50]
        punjabi_Cuisine={ "Punjabi food":x,"Price":y}
        import pandas as pd
        df=pd.DataFrame(punjabi_Cuisine)
        print("\n\n Punjabi foods \n\n")
        print(df)
        d=[]
        while x:
            x=True
            b=int(input("Enter the position value:"))
            c=int(input("Enter the Quantity:"))
            z=y[b]
            ytotal=z*c
            d.append(ytotal)
            x=input("Do you want to reorder")
            if x=="no":
                print("Thank you")
                break
        t=sum(d)
        m=(t*0.05)
        k=t+m
        from colorama import Fore,Back,Style
        print(Fore.BLACK+Back.RED+Style.BRIGHT+"servicetax=5%")
        print("Total Amount:",t,"Rupees:")
        print("Total Amount including Service Tax:",k,"Rupees")
    def Gujrati_Cuisine(rp):
        x=["Dal Dhokli","Dhokla","khakra","Jalebi phafhda"]
        y=[50,45,120,100]
        gujrati_cuisine={"Gujrati food":x,"Price":y}
        import pandas as pd
        df=pd.DataFrame(gujrati_cuisine)
        print("\n\n Gujrati foods \n\n")
        print(df)
        d=[]
        while x:
            x=True
            b=int(input("Enter the position value:"))
            c=int(input("Enter the Quantity:"))
            z=y[b]
            ytotal=z*c
            d.append(ytotal)
            x=input("Do you want to reorder")
            if x=="no":
                print("Thank you")
                break
        t=sum(d)
        m=(t*0.10)
        k=t+m
        from colorama import Fore,Back,Style
        print(Fore.BLACK+Back.GREEN+Style.BRIGHT+"servicetax=10%")
        print("Total Amount:",t,"Rupees:")
        print("Total Amount including Service Tax:",k,"Rupees")
        
    def Maharashtra_Cuisine(rp):
        x=["Vada Pav","Puran poli","Pav bhaji","Modak"]
        y=[50,150,120,250]
        Maharashtri_cuisine={"Maharatra food":x,"Price":y}
        import pandas as pd
        df=pd.DataFrame(Maharashtri_cuisine)
        print("\n\n Maharashtri foods \n\n")
        print(df)
        d=[]
        while x:
            x=True
            b=int(input("Enter the position value:"))
            c=int(input("Enter the Quantity:"))
            z=y[b]
            ytotal=z*c
            d.append(ytotal)
            x=input("Do you want to reorder")
            if x=="no":
                print("Thank you")
                break
        t=sum(d)
        m=(t*0.10)
        k=t+m
        from colorama import Fore,Back,Style
        print(Fore.BLACK+Back.YELLOW+Style.BRIGHT+"servicetax=10%")
        print("Total Amount:",t,"Rupees:")
        print("Total Amount including Service Tax:",k,"Rupees")

# %%
obj=Cuisines()
# Out:
# 				 JMD Restaurant
# 				 started 2024
# 				 near Cokhi Dhani
#
#
# 				 MENU
#
#
#  Rajasthani_Cuisine
#
#
#  Punjabi Cuisine
#
#
#  Gujrati Cuisine
#
#
#  Maharashtra Cuisine

# %%
x=input("Enter the name of Cuisine")
if x=="Rajasthani_Cuisine":
    obj.Rajasthani_Cuisine()
elif x=="Punjabi_Cuisine":
    obj.Punjabi_Cuisine()
elif x=="Gujrati_Cuisine":
    obj.Gujrati_Cuisine()
elif x=="Maharashtra_Cuisine":
    obj.Maharashtra_Cuisine()
# Out:
# Enter the name of Cuisine Maharashtra_Cuisine
#  Maharashtri foods
#
#
#   Maharatra food  Price
# 0       Vada Pav     50
# 1     Puran poli    150
# 2      Pav bhaji    120
# 3          Modak    250
# Enter the position value: 2
# Enter the Quantity: 1
# Do you want to reorder no
# Thank you
# servicetax=10%
# Total Amount: 120 Rupees:
# Total Amount including Service Tax: 132.0 Rupees
